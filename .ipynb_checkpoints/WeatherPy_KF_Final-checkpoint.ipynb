# %%
#import dependencies
# %matplotlib notebook
import csv
import numpy as np
import pandas as pd
import requests
import seaborn as sns
import matplotlib.pyplot as plt
from config import api_key
from citipy import citipy
import random
import json
from pprint import pprint
import time

# %%
#import all the possible cities in the open weather current weasther api
current_open_cities =open('city.list.json').read()
possible_cities = json.loads(current_open_cities)
#pprint(possible_cities)
city_list_max = len(possible_cities)
city_list_max
num_min = 0

# %%
#take the number of possible cities and shuffle them to get an unduplicated list of random numbers
num_list = list(range(num_min,city_list_max,1))
random.shuffle(num_list)

# %%
#get the city id's for the 750 randomly selected numbers
city_id_list = []
i = 0
for i in range(750):
    city_id_list.append(possible_cities[num_list[i]]["id"])
#len(city_id_list)

# %%
api_url = 'http://api.openweathermap.org/data/2.5/weather?id='
units = 'imperial'
urlend = '&appid={}&units={}'.format( api_key, units)

# %%
#lists to hold individual data points for each city
city_id = []
city_name = []
city_country = []
city_lat = []
city_lon = []
city_temp = []
city_humid = []
city_cloudiness = []
city_wind = []
i = 0
#for-loop to meet the api call limit of 60 calls per minute. This should take about 4 minutes to run
for x in range(15):
    
    for i in range(50):
        response = requests.get(api_url + str(city_id_list[i])+ urlend).json()
        #print(json.dumps(response, indent=1, sort_keys=False))
        city_id.append(response['id'])
        city_name.append(response['name'])
        city_country.append(response['sys']['country'])
        city_lat.append(response['coord']['lat'])
        city_lon.append(response['coord']['lon'])
        city_temp.append(response['main']['temp_max'])
        city_humid.append(response['main']['humidity'])
        city_cloudiness.append(response['clouds']['all'])
        city_wind.append(response['wind']['speed'])
        i = i+50
    time.sleep(61)
print('Finished Running')
# Out:
# Finished Running

# %%
#create dictionary to display and use the city data pulled above
city_dict = {
    'API_City_ID': city_id,
    'City':city_name,
    'Country_Code': city_country,
    'Latitude':city_lat,
    'Longitude':city_lon,
    'Max Tempurature (F)':city_temp,
    'Humidity':city_humid,
    'Cloudiness_%':city_cloudiness,
    'Wind_(mph)':city_wind 
}
city_data = pd.DataFrame(city_dict)
city_data.head()
# Out:
#    API_City_ID        City Country_Code  Latitude  Longitude  \
# 0      4850657       Cedar           US     41.21     -92.53
# 1      2652557  Collington           GB     52.25      -2.52
# 2      2813397         Weg           DE     47.70      10.60
# 3       258377   Ligourion           GR     37.62      23.03
# 4      1607097       Raman           TH      6.48     101.42
#
#    Max Tempurature (F)  Humidity  Cloudiness_%  Wind_(mph)
# 0                 84.2        61             1        4.50
# 1                 68.0        82            75        8.05
# 2                 82.4        30             0        8.05
# 3                 82.4        34            40       12.75
# 4                 78.8        94            20        2.24

# %%
city_data.to_csv('plot_cities.csv')

# %%
city_data = pd.read_csv('plot_cities.csv')

# %%
# Build 1st scatter plot
plt.figure(1)
plt.scatter(city_data["Latitude"], city_data["Max Tempurature (F)"], marker="o", edgecolor='black',alpha = .50)
plt.title("City Latitude vs. Max Tempurature")
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)
#plt.xlim(-90,90,2)
#plt.ylim(0,110,10)


# Save the figure
plt.savefig("Temperature_F_vs_Latitude.png")
plt.tight_layout()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Build 2nd scatter plot
plt.figure(2)
plt.scatter(city_data["Latitude"], city_data["Humidity"], marker="o", edgecolor='black',alpha = .50)
plt.title("City Latitude vs. Humidity (%)")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)
#plt.xlim(-90,90,20)
#plt.ylim(0,105,20)
# Save the figure
plt.savefig("Humidity_vs_Latitude.png")

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Build 3rd scatter plot
plt.figure(3)
plt.scatter(city_data["Latitude"], city_data['Cloudiness_%'], marker="o", edgecolor='black',alpha = .50)
plt.title("City Latitude vs. Cloudiness (%)")
plt.ylabel("Cloudiness_%")
plt.xlabel("Latitude")
plt.grid(True)
#plt.xlim(-90,90,10)
#plt.ylim(5,105,10)
# Save the figure
plt.savefig("Cloudiness_%_vs_Latitude.png")

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Build 4th scatter plot
plt.figure(4)
plt.scatter(city_data["Latitude"], city_data['Wind_(mph)'], marker="o", edgecolor='black',alpha = .50)
plt.title("City Latitude vs. Wind_(mph)")
plt.ylabel("Wind_(mph)")
plt.xlabel("Latitude")
plt.grid(True)
#plt.xlim(-90,90,10)
#plt.ylim(0,20,2)
# Save the figure
plt.savefig("Wind_mph_%_vs_Latitude.png")

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
